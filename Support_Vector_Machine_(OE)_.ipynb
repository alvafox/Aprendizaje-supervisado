# %% [markdown]
# <a href="https://colab.research.google.com/github/alvafox/Aprendizaje-supervisado/blob/main/Support_Vector_Machine_(OE)_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Clasificador de Objetivos de Estudio (SVM)**

# %% [markdown]
# SVM significa "Support Vector Machine" o "Máquina de Vectores de Soporte" en español. Es un tipo de modelo de aprendizaje supervisado utilizado para la clasificación o regresión.
#
# Las SVM encuentran el hiperplano que mejor separa los datos de diferentes clases en un espacio de alta dimensionalidad. El hiperplano es una superficie que separa los datos de diferentes clases de manera óptima. Los vectores de soporte son los puntos más cercanos al hiperplano y son importantes para definir la ubicación del hiperplano.
#
# Las SVM se utilizan comúnmente en aplicaciones de aprendizaje automático debido a su capacidad para manejar conjuntos de datos grandes y complejos, y pueden funcionar bien en conjuntos de datos con varias clases. Los SVM también pueden ser eficaces en problemas de regresión al encontrar el hiperplano que mejor se ajusta a los datos de entrenamiento.
#
# En resumen, SVM es la abreviatura de "Support Vector Machine" o "Máquina de Vectores de Soporte", y se utiliza para resolver problemas de clasificación o regresión en el aprendizaje supervisado.

# %% [markdown]
# ## Importar librerías
# ---

# %%
# importar bibliotecas
import numpy as np
import pandas as pd
import string
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix 
from sklearn import metrics

# matplotlib imports are used to plot confusion matrices for the classifiers
import matplotlib as mpl 
import matplotlib.cm as cm 
import matplotlib.pyplot as plt

# %%
# !pip install ftfy
import ftfy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ftfy in /usr/local/lib/python3.9/dist-packages (6.1.1)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.9/dist-packages (from ftfy) (0.2.6)

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv("/gdrive/MyDrive/INSUMOS/DOCTORADOS (2021-2023).csv", sep=";",encoding="latin1")
df = df.fillna("-")
df
# Out:
#        AÑO     FOLIO                       COMITÉ INICIAL (TP)  \
# 0     2021  21210001             Ecología y Ciencias Naturales
# 1     2021  21210002                   Cs. de la Ingeniería II
# 2     2021  21210003              Biología Celular y Molecular
# 3     2021  21210004  Cs. Políticas y Estudios Internacionales
# 4     2021  21210005                            Administración
# ...    ...       ...                                       ...
# 6225  2023  21232432                             Biotecnología
# 6226  2023  21232435                                 Filosofía
# 6227  2023  21232438                                   Derecho
# 6228  2023  21232439                      Agronomía y Forestal
# 6229  2023  21232441                                  Economía
#
#              COMITÉ DEFINITIVO (L2)  \
# 0     Ecología y Ciencias Naturales
# 1           Cs. de la Ingeniería II
# 2      Biología Celular y Molecular
# 3                           Derecho
# 4                    Administración
# ...                             ...
# 6225                  Biotecnología
# 6226                      Filosofía
# 6227                        Derecho
# 6228           Agronomía y Forestal
# 6229                       Economía
#
#                                                OBJETIVO  \
# 0     Contaminación, tecnología y remediación del ag...
# 1     La pérdida de piezas dentales afecta la calida...
# 2     La lesión de médula espinal (LME) es una condi...
# 3     La evaluación del cumplimiento efectivo que se...
# 4     1.- Debido al rol que cumplen las IES en la fo...
# ...                                                 ...
# 6225  La flavobacteriosis es una enfermedad provocad...
# 6226  Mi objetivo de estudio consiste en elaborar un...
# 6227  \r\nEstoy  desarrollando mi investigación de D...
# 6228  La tesis se alinea con el objetivo del program...
# 6229  Mis líneas de investigación son Economía del D...
#
#                                                PROGRAMA  \
# 0     Doctorado en Ciencias Ambientales mención Sist...
# 1                   Doctorado en Ingeniería Metalúrgica
# 2     Doctorado en Ciencias Biológicas mención Biolo...
# 3                         Doctorado en Ciencia Política
# 4                         Doctorado en Ciencias Humanas
# ...                                                 ...
# 6225                         Doctorado en Biotecnología
# 6226    Doctorado en Filosofía con mención en Filosofía
# 6227                               Doctorado en Derecho
# 6228            Doctorado en Ciencias de la Agricultura
# 6229                              Doctorado en Economía
#
#                                              PALABRAS 1  \
# 0     2513 Ciencias Ambientales - 1 Tratamiento, dep...
# 1     3312 Tecnología de materiales - 12 Ensayos de ...
# 2            2407 Biología celular - 01 Cultivo celular
# 3     5905 Política Comparada - 01 Instituciones Pol...
# 4     6103 Psicología industrial, del trabajo y de l...
# ...                                                 ...
# 6225  2412 Inmunología (ver 2302.16, 3109.03, 3207.1...
# 6226  7201 Filosofía del conocimiento - 02 Epistemol...
# 6227        5699 Otras especialidades jurídicas - otras
# 6228  3103 Agronomía (ver 2417 y 5312.01 ) - 04 Prot...
# 6229        5302 Econometría - 02 Modelos econométricos
#
#                                              PALABRAS 2  \
# 0     2513 Ciencias Ambientales - 18 Gestión de resi...
# 1      3315 Tecnología metalúrgica - 11 Pulvimetalurgia
# 2         2407 Biología celular - 05 Cultivo de tejidos
# 3                                                     -
# 4                                                     -
# ...                                                 ...
# 6225  2412 Inmunología (ver 2302.16, 3109.03, 3207.1...
# 6226  7202 Antropología filosófica - 07 Filosofía de...
# 6227                                                  -
# 6228  3103 Agronomía (ver 2417 y 5312.01 ) - 05 Técn...
# 6229   5308 Economía general - 01 Metodología económica
#
#                                              PALABRAS 3
# 0                                                     -
# 1                                                     -
# 2       2407 Biología celular - 06 Regeneración tisular
# 3                                                     -
# 4                                                     -
# ...                                                 ...
# 6225                                                  -
# 6226  7207 Filosofía social - 01 Filosofia de la cul...
# 6227                                                  -
# 6228                                                  -
# 6229                                                  -
#
# [6230 rows x 9 columns]

# %%
pd.set_option("display.max_rows", 152)
df.groupby(["COMITÉ INICIAL (TP)","COMITÉ DEFINITIVO (L2)"])["FOLIO"].count().to_frame()
# Out:
#                                                                                                    FOLIO
# COMITÉ INICIAL (TP)                                COMITÉ DEFINITIVO (L2)
# Administración                                     Administración                                     68
#                                                    Cs. de la Ingeniería I                              1
# Agronomía y Forestal                               Agronomía y Forestal                              271
#                                                    Cs. Químicas                                        1
#                                                    Cs. Veterinarias                                    1
#                                                    Cs. de la Ingeniería II                             1
#                                                    Ecología y Ciencias Naturales                       1
#                                                    Políticas Públicas y Administración del Estado      1
# Arquitectura                                       Arquitectura                                       49
#                                                    Filosofía                                           1
# Arte                                               Arte                                               64
# Biología Celular y Molecular                       Biología Celular y Molecular                      352
#                                                    Biología Fisiológica y Bioquímica                   1
#                                                    Ecología y Ciencias Naturales                       1
# Biología Fisiológica y Bioquímica                  Agronomía y Forestal                                1
#                                                    Biología Celular y Molecular                        3
#                                                    Biología Fisiológica y Bioquímica                 253
#                                                    Biotecnología                                       4
#                                                    Cs. Médicas                                         2
#                                                    Ecología y Ciencias Naturales                       3
#                                                    Letras                                              1
# Biotecnología                                      Biotecnología                                     345
#                                                    Cs. Médicas                                         4
#                                                    Cs. de la Ingeniería II                             1
# Computación e Informática                          Agronomía y Forestal                                1
#                                                    Computación e Informática                         167
#                                                    Cs. de la Ingeniería I                              2
#                                                    Educación I                                         1
#                                                    Física y Astronomía                                 1
# Comunicación                                       Comunicación                                       63
#                                                    Historia, Antropología y Arqueología                1
#                                                    Sociología                                          1
# Cs. Matemáticas                                    Cs. Matemáticas                                   240
#                                                    Cs. de la Ingeniería I                              1
#                                                    Educación I                                         1
#                                                    Psicología                                          1
# Cs. Médicas                                        Biología Celular y Molecular                        2
#                                                    Biología Fisiológica y Bioquímica                   5
#                                                    Biotecnología                                       2
#                                                    Cs. Médicas                                       313
#                                                    Educación II                                        1
#                                                    Psicología                                          1
# Cs. Políticas y Estudios Internacionales           Cs. Médicas                                         1
#                                                    Cs. Políticas y Estudios Internacionales           72
#                                                    Derecho                                             2
#                                                    Economía                                            1
#                                                    Filosofía                                           1
#                                                    Historia, Antropología y Arqueología                1
#                                                    Políticas Públicas y Administración del Estado      3
# Cs. Químicas                                       Biología Celular y Molecular                        8
#                                                    Biología Fisiológica y Bioquímica                  16
#                                                    Biotecnología                                      11
#                                                    Cs. Químicas                                      349
#                                                    Cs. Veterinarias                                    1
#                                                    Cs. de la Ingeniería II                             6
#                                                    Educación I                                         1
#                                                    Física y Astronomía                                 1
# Cs. Veterinarias                                   Biología Fisiológica y Bioquímica                   2
#                                                    Biotecnología                                       7
#                                                    Computación e Informática                           1
#                                                    Cs. Veterinarias                                  140
#                                                    Ecología y Ciencias Naturales                       5
# Cs. de la Ingeniería I                             Administración                                     12
#                                                    Agronomía y Forestal                                2
#                                                    Biología Celular y Molecular                        1
#                                                    Biotecnología                                       1
#                                                    Computación e Informática                          24
#                                                    Comunicación                                        1
#                                                    Cs. Matemáticas                                     4
#                                                    Cs. de la Ingeniería I                            267
#                                                    Cs. de la Ingeniería II                             9
#                                                    Economía                                            1
#                                                    Educación I                                         1
#                                                    Física y Astronomía                                 2
#                                                    Políticas Públicas y Administración del Estado      1
#                                                    Urbanismo y Asentamientos Humanos                   2
# Cs. de la Ingeniería II                            Computación e Informática                           1
#                                                    Cs. Matemáticas                                     1
#                                                    Cs. de la Ingeniería I                              3
#                                                    Cs. de la Ingeniería II                           476
#                                                    Geología y Oceanografía                             1
# Derecho                                            Derecho                                           161
#                                                    Educación I                                         1
#                                                    Sociología                                          1
# Diseño                                             Diseño                                              7
# Ecología y Ciencias Naturales                      Agronomía y Forestal                                1
#                                                    Biología Celular y Molecular                        6
#                                                    Biología Fisiológica y Bioquímica                   2
#                                                    Biotecnología                                       4
#                                                    Cs. Matemáticas                                     1
#                                                    Cs. Químicas                                        1
#                                                    Cs. de la Ingeniería II                             4
#                                                    Ecología y Ciencias Naturales                     315
#                                                    Física y Astronomía                                 3
#                                                    Geología y Oceanografía                             5
#                                                    Psicología                                          1
#                                                    Urbanismo y Asentamientos Humanos                   1
# Economía                                           Cs. Matemáticas                                     2
#                                                    Cs. de la Ingeniería I                              1
#                                                    Economía                                           58
# Educación I                                        Educación I                                       144
# Educación II                                       Cs. Médicas                                         2
#                                                    Educación II                                      104
# Filosofía                                          Arte                                                1
#                                                    Cs. Políticas y Estudios Internacionales            1
#                                                    Educación II                                        2
#                                                    Filosofía                                         162
#                                                    Historia, Antropología y Arqueología                4
#                                                    Letras                                              2
#                                                    Psicología                                          2
#                                                    Sociología                                          1
#                                                    Urbanismo y Asentamientos Humanos                   1
# Física y Astronomía                                Física y Astronomía                               396
# Geología y Oceanografía                            Agronomía y Forestal                                1
#                                                    Computación e Informática                           1
#                                                    Cs. Matemáticas                                     1
#                                                    Cs. Veterinarias                                    1
#                                                    Cs. de la Ingeniería II                             2
#                                                    Ecología y Ciencias Naturales                      14
#                                                    Geología y Oceanografía                           111
#                                                    Psicología                                          1
# Historia, Antropología y Arqueología               Historia, Antropología y Arqueología              250
# Letras                                             Arte                                                1
#                                                    Letras                                            179
#                                                    Sociología                                          1
# Políticas Públicas y Administración del Estado     Cs. Médicas                                         1
#                                                    Políticas Públicas y Administración del Estado      2
#                                                    Sociología                                          1
# Políticas Públicas y Administración del Estado     Economía                                            1
#                                                    Políticas Públicas y Administración del Estado     11
# Psicología                                         Cs. Políticas y Estudios Internacionales            1
#                                                    Educación II                                        2
#                                                    Filosofía                                           1
#                                                    Letras                                              1
#                                                    Psicología                                        284
#                                                    Sociología                                          3
# Sociología                                         Arte                                                1
#                                                    Comunicación                                        3
#                                                    Cs. Políticas y Estudios Internacionales            2
#                                                    Economía                                            1
#                                                    Educación II                                        1
#                                                    Filosofía                                           2
#                                                    Historia, Antropología y Arqueología               14
#                                                    Letras                                              1
#                                                    Políticas Públicas y Administración del Estado      6
#                                                    Psicología                                          5
#                                                    Sociología                                        123
# Urbanismo y Asentamientos Humanos                  Ecología y Ciencias Naturales                       2
#                                                    Geología y Oceanografía                             3
#                                                    Historia, Antropología y Arqueología                3
#                                                    Sociología                                          3
#                                                    Urbanismo y Asentamientos Humanos                 119

# %%
# crear el gráfico de barras
df.groupby(["COMITÉ DEFINITIVO (L2)"])["FOLIO"].count().sort_values().plot(kind='barh', legend=False)
# Out:
# <Axes: ylabel='COMITÉ DEFINITIVO (L2)'>

# %% [markdown]
# Eliminaremos algunas palabras.

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stopwords = set(stopwords.words('spanish'))
print(stopwords)
stopwords.update(["embargo", "además", "través", "estudio", "mediante", "propuesta", "debido", "investigación", \
                  "chile", "proceso", "objetivo", "desarrollo", "trabajo", "así", "forma", "línea", "contexto", "tipo",\
                  "importante", "diferente", "posible", "manera", "dentro", "sido", "ello", "sistema", "modelo", "uso",\
                  "parte", "efecto", "proyecto", "problema", "estudios", "análisis","procesos", "área", "parte", \
                  "producción", "conocimiento", "relación", "año", "caso", "dato", "datos", "cambio", "sistemas", \
                  "resultado", "partir", "base", "grupo", "diferentes", "estructura", "mecanismo", "evaluar",\
                  "doctorado", "ejemplo", "cuales", "analizar", "impacto", "siendo", "si", "pueden", "frente",\
                  "método", "mayor", "actualmente", "existe", "principalmente", "presente", "gran", "solo", "punto",\
                  "bien", "sino", "años", "lado", "fin", "basado", "ser", "puede", "respecto", "vez", "mismo", "estudiar",\
                  "formación", "información", "país", "tiempo", "teoría", "interés", "determinar", "desarrollar", "resultados"\
                  "persona", "último", "cómo", "condicione", "medio", "respuesta", "estrategia", "general", "nivel", "programa",\
                  "experiencia", "bajo", "control", "producto", "capacidad", "nuevo", "nueva", "enfoque", "aporte", "problemas",\
                  "factores", "generar", "cabo", "debe", "podría", "realizar", "cada", "rol", "et", "and"])

stopwords= list(stopwords)
print(stopwords)


def clean(doc): # doc is a string of text
    doc = ftfy.fix_text(doc)
    doc = doc.replace("</br>", " ") # This text contains a lot of <br/> tags.
    doc = doc.replace("\n", "") 
    doc = doc.replace("\n\n", "") 
    doc = doc.replace("\n\n\n", "") 
    doc = "".join([char for char in doc if char not in string.punctuation and not char.isdigit()])
    doc = " ".join([token for token in doc.split() if token not in stopwords])
    # remove punctuation and numbers
    return doc
# Out:
# {'he', 'los', 'tendría', 'estuvisteis', 'muchos', 'como', 'al', 'eras', 'éramos', 'tendrían', 'hay', 'tus', 'tuviésemos', 'estuvieses', 'mi', 'serán', 'estabas', 'tengan', 'esto', 'tendrán', 'esa', 'habremos', 'tengas', 'estamos', 'tened', 'tenga', 'habrían', 'siente', 'teníamos', 'era', 'tuyo', 'tuvieron', 'hemos', 'otras', 'estaréis', 'fuésemos', 'estuvo', 'en', 'con', 'sentidas', 'su', 'otro', 'sea', 'hube', 'serás', 'a', 'pero', 'esté', 'mucho', 'tuvimos', 'habréis', 'el', 'fuese', 'yo', 'cuando', 'le', 'tuyas', 'fuera', 'están', 'habríamos', 'sentid', 'hayan', 'tienes', 'tu', 'o', 'mías', 'estuviésemos', 'sería', 'mío', 'tengamos', 'eso', 'vuestro', 'seríais', 'habiendo', 'habido', 'fueses', 'estuviesen', 'estoy', 'estaba', 'habíamos', 'estadas', 'soy', 'habida', 'habidos', 'hubieses', 'vuestra', 'tenemos', 'algunos', 'este', 'habré', 'nosotros', 'hubimos', 'eres', 'un', 'serían', 'seré', 'fueras', 'esta', 'estéis', 'suyos', 'muy', 'lo', 'fuesen', 'somos', 'habría', 'tenías', 'tuvierais', 'hubiesen', 'estos', 'han', 'estuvieseis', 'hubiese', 'qué', 'una', 'estuvimos', 'fuerais', 'habrá', 'las', 'teníais', 'estuvieras', 'contra', 'tenía', 'hubierais', 'sin', 'otros', 'estaríais', 'e', 'fueron', 'quienes', 'fueseis', 'algunas', 'ti', 'sintiendo', 'él', 'ya', 'se', 'fuiste', 'vuestras', 'tuvieran', 'fueran', 'del', 'tú', 'hubieras', 'sus', 'nuestras', 'había', 'tuvieses', 'algo', 'habríais', 'estaban', 'vosotros', 'la', 'habías', 'estés', 'hubiésemos', 'seáis', 'otra', 'todos', 'durante', 'antes', 'habéis', 'hubo', 'hayáis', 'seamos', 'hubiera', 'fuimos', 'seríamos', 'habrías', 'eran', 'será', 'donde', 'estábamos', 'nuestros', 'no', 'seremos', 'que', 'estarás', 'habidas', 'tendríamos', 'estuviese', 'seréis', 'estás', 'estarías', 'tendremos', 'hubieseis', 'suyas', 'estuviéramos', 'entre', 'tuviéramos', 'habían', 'estarían', 'estuve', 'sentido', 'ella', 'sobre', 'poco', 'ha', 'uno', 'estabais', 'hubisteis', 'nada', 'tenida', 'míos', 'estaré', 'fui', 'nosotras', 'nuestro', 'estaríamos', 'hubieran', 'porque', 'estada', 'teniendo', 'tuvieseis', 'tengáis', 'también', 'tuvo', 'tendrá', 'hayas', 'sentida', 'sean', 'estuvieran', 'tenido', 'estará', 'nos', 'tiene', 'es', 'tengo', 'ante', 'tanto', 'estuviera', 'está', 'tuviste', 'suyo', 'tendréis', 'hayamos', 'habrán', 'tuvieras', 'tendrías', 'para', 'sentidos', 'ni', 'cual', 'habíais', 'mía', 'tenidas', 'estar', 'tuve', 'has', 'estados', 'tendré', 'ese', 'tuyos', 'todo', 'suya', 'ellas', 'mis', 'tuviera', 'haya', 'estaremos', 'quien', 'estuvierais', 'ellos', 'hubiéramos', 'tendríais', 'estáis', 'tuya', 'tenidos', 'habrás', 'te', 'estaría', 'unos', 'tuviese', 'y', 'de', 'mí', 'sí', 'estuviste', 'estando', 'hubiste', 'os', 'sois', 'por', 'estado', 'tuviesen', 'serías', 'erais', 'estarán', 'vosotras', 'fue', 'hasta', 'tendrás', 'fuisteis', 'esos', 'fuéramos', 'tenéis', 'más', 'hubieron', 'estemos', 'son', 'tuvisteis', 'vuestros', 'seas', 'estén', 'nuestra', 'esas', 'estuvieron', 'estad', 'tenían', 'desde', 'les', 'estas', 'me', 'tienen'}
# ['sistema', 'he', 'bajo', 'los', 'doctorado', 'tendría', 'mayor', 'estuvisteis', 'muchos', 'embargo', 'estudios', 'procesos', 'como', 'al', 'eras', 'éramos', 'tendrían', 'analizar', 'hay', 'tus', 'ello', 'tuviésemos', 'rol', 'estructura', 'siendo', 'estuvieses', 'mi', 'serán', 'partir', 'estabas', 'tengan', 'esto', 'tendrán', 'esa', 'habremos', 'tengas', 'estamos', 'tened', 'tenga', 'habrían', 'grupo', 'siente', 'teníamos', 'era', 'tuyo', 'respecto', 'parte', 'tuvieron', 'hemos', 'otras', 'estaréis', 'objetivo', 'fuésemos', 'datos', 'estuvo', 'en', 'con', 'sentidas', 'su', 'otro', 'sea', 'determinar', 'importante', 'hube', 'serás', 'a', 'pero', 'esté', 'mucho', 'tuvimos', 'habréis', 'el', 'fuese', 'pueden', 'mediante', 'mecanismo', 'yo', 'cuando', 'le', 'tuyas', 'fuera', 'están', 'habríamos', 'sentid', 'hayan', 'tienes', 'tu', 'o', 'mías', 'estuviésemos', 'sería', 'producción', 'chile', 'mío', 'tengamos', 'eso', 'vuestro', 'seríais', 'habiendo', 'bien', 'habido', 'fueses', 'enfoque', 'estuviesen', 'último', 'ser', 'estoy', 'estaba', 'habíamos', 'estadas', 'soy', 'habida', 'existe', 'habidos', 'hubieses', 'vuestra', 'tenemos', 'sido', 'nuevo', 'algunos', 'este', 'habré', 'nosotros', 'hubimos', 'eres', 'un', 'serían', 'seré', 'fueras', 'esta', 'formación', 'estéis', 'suyos', 'muy', 'proyecto', 'debido', 'lo', 'fuesen', 'control', 'somos', 'habría', 'tenías', 'puede', 'además', 'tuvierais', 'posible', 'desarrollar', 'hubiesen', 'estos', 'han', 'estuvieseis', 'desarrollo', 'hubiese', 'qué', 'una', 'estuvimos', 'fuerais', 'habrá', 'las', 'teníais', 'estuvieras', 'contra', 'tenía', 'hubierais', 'sin', 'diferente', 'cómo', 'otros', 'estaríais', 'evaluar', 'diferentes', 'e', 'método', 'fueron', 'quienes', 'fueseis', 'cada', 'algunas', 'efecto', 'relación', 'año', 'ti', 'sintiendo', 'él', 'ya', 'se', 'fuiste', 'vuestras', 'tuvieran', 'fueran', 'del', 'propuesta', 'condicione', 'tiempo', 'tú', 'hubieras', 'sus', 'nuestras', 'gran', 'había', 'tuvieses', 'algo', 'problema', 'solo', 'habríais', 'estaban', 'vosotros', 'frente', 'fin', 'la', 'habías', 'lado', 'estés', 'hubiésemos', 'uso', 'seáis', 'otra', 'teoría', 'todos', 'durante', 'antes', 'habéis', 'hubo', 'estrategia', 'hayáis', 'seamos', 'vez', 'debe', 'producto', 'hubiera', 'fuimos', 'seríamos', 'habrías', 'impacto', 'eran', 'será', 'donde', 'estábamos', 'nuestros', 'si', 'no', 'seremos', 'factores', 'que', 'estarás', 'habidas', 'tendríamos', 'estuviese', 'base', 'seréis', 'estás', 'estarías', 'mismo', 'cambio', 'tendremos', 'respuesta', 'hubieseis', 'caso', 'realizar', 'resultadospersona', 'problemas', 'suyas', 'estuviéramos', 'entre', 'tuviéramos', 'país', 'habían', 'estarían', 'estuve', 'actualmente', 'sentido', 'ella', 'sobre', 'poco', 'ha', 'uno', 'estabais', 'hubisteis', 'dato', 'nada', 'tenida', 'contexto', 'míos', 'estaré', 'fui', 'nosotras', 'nivel', 'experiencia', 'cabo', 'nuestro', 'estaríamos', 'hubieran', 'porque', 'estada', 'teniendo', 'ejemplo', 'tuvieseis', 'tengáis', 'aporte', 'también', 'así', 'tuvo', 'sistemas', 'estudiar', 'tendrá', 'hayas', 'sentida', 'dentro', 'modelo', 'sean', 'manera', 'estuvieran', 'tenido', 'estará', 'nos', 'tiene', 'investigación', 'es', 'tengo', 'ante', 'tanto', 'estuviera', 'está', 'interés', 'medio', 'tuviste', 'suyo', 'tendréis', 'and', 'hayamos', 'basado', 'habrán', 'tuvieras', 'tendrías', 'generar', 'para', 'capacidad', 'sentidos', 'ni', 'cual', 'habíais', 'mía', 'tenidas', 'estar', 'tuve', 'través', 'has', 'estados', 'área', 'tendré', 'ese', 'principalmente', 'estudio', 'proceso', 'tuyos', 'años', 'todo', 'suya', 'ellas', 'podría', 'mis', 'forma', 'tuviera', 'haya', 'estaremos', 'quien', 'estuvierais', 'ellos', 'hubiéramos', 'tendríais', 'estáis', 'tuya', 'tenidos', 'nueva', 'cuales', 'habrás', 'te', 'estaría', 'unos', 'línea', 'tuviese', 'y', 'de', 'conocimiento', 'mí', 'sí', 'estuviste', 'programa', 'estando', 'hubiste', 'general', 'resultado', 'os', 'tipo', 'sois', 'por', 'estado', 'punto', 'tuviesen', 'serías', 'erais', 'trabajo' ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# preparar los datos
# Seleccionar las características
labels = df["COMITÉ DEFINITIVO (L2)"]
features = df["PROGRAMA"] + " " + df["OBJETIVO"] + " " + df["PALABRAS 1"]

objetivos = df["OBJETIVO"]
programas = df["PROGRAMA"]
comites_antes = df["COMITÉ INICIAL (TP)"]
palabras_uno = df["PALABRAS 1"]
palabras_dos = df["PALABRAS 2"]
palabras_tres = df["PALABRAS 3"]

# %% [markdown]
# # Vectorización de los datos
# ---

# %% [markdown]
# A continuación, utilizamos la técnica de Bolsa de Palabras para extraer características de los objetivos de estudio

# %%
# Vectorizar las características de texto
vectorizer = CountVectorizer(preprocessor=clean)

X = vectorizer.fit_transform(features).toarray()

from sklearn.preprocessing import normalize
X_normalized = normalize(X, norm='l2')

#objetivos_vec = vectorizer.fit_transform(objetivos).toarray()
#programas_vec = vectorizer.fit_transform(programas).toarray()
#palabras_uno_vec = vectorizer.fit_transform(palabras_uno).toarray()


#from sklearn.preprocessing import normalize

#X_normalized = normalize(X, norm='l2')
#palabras_dos_vec = vectorizer.fit_transform(palabras_dos).toarray()
#palabras_tres_vec = vectorizer.fit_transform(palabras_tres).toarray()
#comites_antes_vec = vectorizer.fit_transform(comites_antes)

caracteristicas = X_normalized 
#caracteristicas = np.hstack((objetivos_vec, programas_vec))
caracteristicas.shape
# Out:
# (6230, 98200)

# %% [markdown]
# En este código, utilizamos CountVectorizer para convertir los atributos en una matriz de características de Bolsa de Palabras. La función fit_transform ajusta el vectorizador a los datos de entrada y luego lo utiliza para transformar los objetivos de estudio en una matriz de características. La función toarray convierte la matriz de características en un arreglo NumPy.

# %% [markdown]
# ## División de los datos para entrenamiento y predicción
# ---

# %% [markdown]
# Después, dividimos los datos en conjuntos de entrenamiento y prueba:

# %%
# dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(caracteristicas, labels, test_size=0.2, random_state=42)

# %% [markdown]
# ## Selección del modelo
# ---

# %% [markdown]
# Seleccionamos el modelo y lo entrenamos:

# %%
# seleccionar el modelo
model = SVC(kernel='linear')

# %% [markdown]
# ## Entrenamiento
# ---

# %%
import time

start = time.time()

# entrenar el modelo
model.fit(X_train, y_train)

end = time.time()

total = end - start
print("Tiempo transcurrido:", round(total/60,2), "minutos")
# Out:
# Tiempo transcurrido: 30.84 minutos

# %%
# Realizar predicciones sobre los datos de prueba
y_pred = model.predict(X_test)

# Evaluar la precisión del modelo
accuracy = accuracy_score(y_test, y_pred)
print("Precisión del modelo: {:.2f}%".format(accuracy * 100))
# Out:
# Precisión del modelo: 80.66%

# %%
comites = list(df["COMITÉ DEFINITIVO (L2)"].unique())
comites.sort()
display(comites)
# Out:
# ['Administración',
#  'Agronomía y Forestal',
#  'Arquitectura',
#  'Arte',
#  'Biología Celular y Molecular',
#  'Biología Fisiológica y Bioquímica',
#  'Biotecnología',
#  'Computación e Informática',
#  'Comunicación',
#  'Cs. Matemáticas',
#  'Cs. Médicas',
#  'Cs. Políticas y Estudios Internacionales',
#  'Cs. Químicas',
#  'Cs. Veterinarias',
#  'Cs. de la Ingeniería I',
#  'Cs. de la Ingeniería II',
#  'Derecho',
#  'Diseño',
#  'Ecología y Ciencias Naturales',
#  'Economía',
#  'Educación I',
#  'Educación II',
#  'Filosofía',
#  'Física y Astronomía',
#  'Geología y Oceanografía',
#  'Historia, Antropología y Arqueología',
#  'Letras',
#  'Políticas Públicas y Administración del Estado',
#  'Psicología',
#  'Sociología',
#  'Urbanismo y Asentamientos Humanos']

# %% [markdown]
# ## Matriz de confusión
# ---

# %%
import itertools
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.YlOrRd):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    # Ajustar los límites de los ejes x e y
    plt.xlim(-0.5, len(classes)-0.5)
    plt.ylim(len(classes)-0.5, -0.5)

    plt.tight_layout()
    plt.ylabel('True label', fontsize=15)
    plt.xlabel('Predicted label', fontsize=15)

# Ejemplo de uso:
cnf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(20,16))
plot_confusion_matrix(cnf_matrix, classes=comites, normalize=True,
                      title='Normalized confusion matrix')
plt.show()

# %%
# calculate AUC: Area under the curve(AUC) gives idea about the model efficiency:
# Further information: https://en.wikipedia.org/wiki/Receiver_operating_characteristic
#cleaner = np.vectorize(clean)
#X_test_clean = cleaner(list(X_test))
#X_test_dtm = vectorizer.transform(X_test_clean)
#y_pred_prob = nb.predict_proba(X_test_dtm)[:, 1]
#print("ROC_AOC_Score: ", roc_auc_score(y_test, y_pred_prob))

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

def plot_confusion_matrix(y_true, y_pred, classes, cmap=plt.cm.Blues):
    cm = confusion_matrix(y_true, y_pred)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title('Confusion matrix')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
plt.figure(figsize=(20,16))
# Ajustar los límites de los ejes x e y
plt.xlim(-0.6, len(comites)-0.5)
plt.ylim(len(comites)-0.5, -0.6)
plot_confusion_matrix(y_test, y_pred, classes=comites)

# %% [markdown]
# ## Predicción
# ---

# %% [markdown]
# Hacemos una predicción utilizando los datos de solo una postulación:

# %%
n = 5899

print("COMITÉ INICIAL (TP) =>", df["COMITÉ INICIAL (TP)"][n])
print("COMITÉ DEFINITIVO (L2) =>", df["COMITÉ DEFINITIVO (L2)"][n])
print("PROGRAMA =>",df["PROGRAMA"][n])
print("PALABRAS 1 =>",df["PALABRAS 1"][n])
print("PALABRAS 2 =>",df["PALABRAS 2"][n])
print("PALABRAS 3 =>",df["PALABRAS 3"][n])
print("OBJETIVO =>",df["OBJETIVO"][n])
# Out:
# COMITÉ INICIAL (TP) => Economía
# COMITÉ DEFINITIVO (L2) => Cs. Matemáticas
# PROGRAMA => Doctorado en Estadística
# PALABRAS 1 => 5302 Econometría - 02 Modelos econométricos
# PALABRAS 2 => 5304 Actividad económica - 06 Dinero y operaciones bancarias
# PALABRAS 3 => -
# OBJETIVO => Mi objetivo de estudio se centra en extender y ampliar resultados en la teoria de modelos econométricos específicamente en analisis predictivo de Series temporales (ST), modelos de Machine Learning (ML). Esta linea de investigación ha sido ampliamente estudiada desde el siglo pasado, teniendo un gran auge en las últimas 4 décadas. La ST estudian problemas que  consiste en  determinar componentes autorregresivos y medias móviles ,tanto para modelos estacionales y no estacionales en ambientes homocedásticos y no  (Modelos ARCH , GARCH y EGARCH) que nos permitan generar un modelo estadístico y asi prever valores futuros para dicha serie.  con el objetivo de  hallar este modelo desconocido  de ST es que tenemos la contribución desde el área de ML con los modelos de corta memoria (LSTM)  que a diferencia de las redes tradicionales no solo puede procesar puntos de datos individuales  sino también secuencias completas de datos , por ende dicha  cualidad diferenciadora permite  aprender a reconstruir series temporales, teniendo en cuenta esta  base común  es que esta teoria en conjunto nos permite abordar temáticas de prediccion como dinámicas de acciones de mercados cruzados(Biplab Bhattacharjee ,Rajiv Kumarb ),Alerta temprana de riesgo financiero sistémico del mercado financiero( Zi-sheng Ouyang, aXi-te Yang  ),Previsión de puntos de inflexión en el precio de las acciones(Pouya KhodaeeAkbar Esfahanipur),Mejora del análisis técnico comercial(Chenjie cantó,Massimo Di Pierro), Pronóstico de acciones  utilizando el sentimiento de los inversores de Twitter (Gabriel Paes Herrera ,Michel Constantino),predicción del tipo de cambio de Bitcoin(wei chen ,Huilin Xu),Predicción de prima de riesgo(Yasin Kutuk ,Lina Barokas),podemos ver su potencial en diferentes dominios, por lo general estos centrados en resolución de un modelo de  ST.Por ende, esta área se centra entorno al análisis estadístico, numérico y a la simulación computacional de sistemas gobernados Series de Tiempo(ST); de ocurrencia frecuente en matemáticas aplicadas y en ciencias como Economia ,Finanzas , Ingenieria, abarcando desde aspectos teóricos fundamentales hasta el desarrollo de investigación aplicada, orientada a la resolución de problemas de origen industrial o económicos.
# Durante el Doctorado bajo la tutela del profesor Rodrigo Salas , analizamos distintas técnicas computacionales de Machine Learning como modelos Fuzzy y LSTM  para modelar series financieras de bitcoin y estimación de necesidad de dinero y cash out de ATM. en este desarrollo me enfoque a estudiar como la descomposición Wavelet nos permitiría encontrar distintos regímenes y asi poder determinar el numero exacto de rezagos para nuestro modelo. Me encuentro estudiando hoy
# modelos de cambio de régimen (Markov Swiching) donde los parámetros varían entre los diferentes regímenes, con un número finito de regímenes. con miras de obtener nuevos resultados al modelar series financieras  dado los cambios  cíclicos en la economía.

# %%
from sklearn.preprocessing import normalize

# ajustar el vectorizador en todo el conjunto de datos
vectorizer.fit(df["PROGRAMA"] + " " + df["OBJETIVO"] + " " + df["PALABRAS 1"])

# utilizar el modelo
comite_inicial = [df["COMITÉ INICIAL (TP)"][n]]
comite_final = [df["COMITÉ DEFINITIVO (L2)"][n]]
folio = [df["FOLIO"][n]]

texto = [df["PROGRAMA"][n] + " " + df["OBJETIVO"][n] + " " + df["PALABRAS 1"][n]]

# Vectorizar las características de texto
X = vectorizer.transform(texto).toarray()
X_normalized = normalize(X, norm='l2')

#Estimación
comite_predicho = model.predict(X_normalized)

print(f"El folio {folio} perteniecía a {comite_inicial} y ahora corresponde a {comite_final} | El modelo pronostica => {comite_predicho}")
# Out:
# El folio [21231890] perteniecía a ['Economía'] y ahora corresponde a ['Cs. Matemáticas'] | El modelo pronostica => ['Cs. Matemáticas']

# %% [markdown]
# Ahora realizaremos predicciones iterando en cada valor del DataFrame.

# %%
# ajustar el vectorizador en todo el conjunto de datos
vectorizer.fit(df["PROGRAMA"] + " " + df["OBJETIVO"] + " " + df["PALABRAS 1"])

# para cada fila en el dataframe, transformar el texto a vector y predecir
for index, row in df.iterrows():
    texto = [row["PROGRAMA"] + " " + row["OBJETIVO"] + " " + row["PALABRAS 1"]]
    X = vectorizer.transform(texto).toarray()
    X_normalized = normalize(X, norm='l2')
    comite_predicho = model.predict(X_normalized)
    df.at[index, "COMITÉ SUGERIDO (SVC)"] = comite_predicho

# %%
df
# Out:
#        AÑO     FOLIO                       COMITÉ INICIAL (TP)  \
# 0     2021  21210001             Ecología y Ciencias Naturales
# 1     2021  21210002                   Cs. de la Ingeniería II
# 2     2021  21210003              Biología Celular y Molecular
# 3     2021  21210004  Cs. Políticas y Estudios Internacionales
# 4     2021  21210005                            Administración
# ...    ...       ...                                       ...
# 6225  2023  21232432                             Biotecnología
# 6226  2023  21232435                                 Filosofía
# 6227  2023  21232438                                   Derecho
# 6228  2023  21232439                      Agronomía y Forestal
# 6229  2023  21232441                                  Economía
#
#              COMITÉ DEFINITIVO (L2)  \
# 0     Ecología y Ciencias Naturales
# 1           Cs. de la Ingeniería II
# 2      Biología Celular y Molecular
# 3                           Derecho
# 4                    Administración
# ...                             ...
# 6225                  Biotecnología
# 6226                      Filosofía
# 6227                        Derecho
# 6228           Agronomía y Forestal
# 6229                       Economía
#
#                                                OBJETIVO  \
# 0     Contaminación, tecnología y remediación del ag...
# 1     La pérdida de piezas dentales afecta la calida...
# 2     La lesión de médula espinal (LME) es una condi...
# 3     La evaluación del cumplimiento efectivo que se...
# 4     1.- Debido al rol que cumplen las IES en la fo...
# ...                                                 ...
# 6225  La flavobacteriosis es una enfermedad provocad...
# 6226  Mi objetivo de estudio consiste en elaborar un...
# 6227  \r\nEstoy  desarrollando mi investigación de D...
# 6228  La tesis se alinea con el objetivo del program...
# 6229  Mis líneas de investigación son Economía del D...
#
#                                                PROGRAMA  \
# 0     Doctorado en Ciencias Ambientales mención Sist...
# 1                   Doctorado en Ingeniería Metalúrgica
# 2     Doctorado en Ciencias Biológicas mención Biolo...
# 3                         Doctorado en Ciencia Política
# 4                         Doctorado en Ciencias Humanas
# ...                                                 ...
# 6225                         Doctorado en Biotecnología
# 6226    Doctorado en Filosofía con mención en Filosofía
# 6227                               Doctorado en Derecho
# 6228            Doctorado en Ciencias de la Agricultura
# 6229                              Doctorado en Economía
#
#                                              PALABRAS 1  \
# 0     2513 Ciencias Ambientales - 1 Tratamiento, dep...
# 1     3312 Tecnología de materiales - 12 Ensayos de ...
# 2            2407 Biología celular - 01 Cultivo celular
# 3     5905 Política Comparada - 01 Instituciones Pol...
# 4     6103 Psicología industrial, del trabajo y de l...
# ...                                                 ...
# 6225  2412 Inmunología (ver 2302.16, 3109.03, 3207.1...
# 6226  7201 Filosofía del conocimiento - 02 Epistemol...
# 6227        5699 Otras especialidades jurídicas - otras
# 6228  3103 Agronomía (ver 2417 y 5312.01 ) - 04 Prot...
# 6229        5302 Econometría - 02 Modelos econométricos
#
#                                              PALABRAS 2  \
# 0     2513 Ciencias Ambientales - 18 Gestión de resi...
# 1      3315 Tecnología metalúrgica - 11 Pulvimetalurgia
# 2         2407 Biología celular - 05 Cultivo de tejidos
# 3                                                     -
# 4                                                     -
# ...                                                 ...
# 6225  2412 Inmunología (ver 2302.16, 3109.03, 3207.1...
# 6226  7202 Antropología filosófica - 07 Filosofía de...
# 6227                                                  -
# 6228  3103 Agronomía (ver 2417 y 5312.01 ) - 05 Técn...
# 6229   5308 Economía general - 01 Metodología económica
#
#                                              PALABRAS 3  \
# 0                                                     -
# 1                                                     -
# 2       2407 Biología celular - 06 Regeneración tisular
# 3                                                     -
# 4                                                     -
# ...                                                 ...
# 6225                                                  -
# 6226  7207 Filosofía social - 01 Filosofia de la cul...
# 6227                                                  -
# 6228                                                  -
# 6229                                                  -
#
#                 COMITÉ SUGERIDO (SVC)
# 0     [Ecología y Ciencias Naturales]
# 1           [Cs. de la Ingeniería II]
# 2      [Biología Celular y Molecular]
# 3                           [Derecho]
# 4                    [Administración]
# ...                               ...
# 6225               [Cs. Veterinarias]
# 6226                      [Filosofía]
# 6227                        [Derecho]
# 6228           [Agronomía y Forestal]
# 6229                       [Economía]
#
# [6230 rows x 10 columns]

# %% [markdown]
# ## Exportar datos
# ---

# %%
df.to_csv("/gdrive/MyDrive/PRODUCTOS/PREDICCIONES (SVC).csv", sep=";",encoding="latin1")

# %%
from google.colab import files
files. download("/gdrive/MyDrive/PRODUCTOS/PREDICCIONES (SVC).csv")
